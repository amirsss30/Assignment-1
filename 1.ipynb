# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
math=['Amir','Asanali','Nurbek','Arthur','Almas']
grades = [100,98,95,75,35]
plt.bar(math,grades )
plt.title('Math Grades')
plt.xlabel('Names')
plt.ylabel('Grades')
# Out:
# Text(0, 0.5, 'Grades')
