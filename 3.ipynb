# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
Days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
Number = [7, 4, 2, 7, 5]
plt.bar(Days, Number)
plt.title('Number of lessons and days of the week of CS-2111 group')
plt.xlabel('Days of the week')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

data_dict = {"Days": ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
            'Number of classes': [7, 4, 2, 7, 5]}
data_df = pd.DataFrame(data_dict)
data_df
# Out:
#         Days  Number of classes
# 0     Monday                  7
# 1    Tuesday                  4
# 2  Wednesday                  2
# 3   Thursday                  7
# 4     Friday                  5
